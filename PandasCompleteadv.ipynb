# %% [markdown]
# <a href="https://colab.research.google.com/github/omkarpattnaik8080/Pandas/blob/main/PandasCompleteadv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
url="https://api.github.com/repos/pandas-dev/pandas/issues"
pd.read_json(url)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                            events_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                              html_url          id  \
# 0     https://github.com/pandas-dev/pandas/pull/57548  2146596329
# 1   https://github.com/pandas-dev/pandas/issues/57547  2146590420
# 2     https://github.com/pandas-dev/pandas/pull/57546  2146235942
# 3     https://github.com/pandas-dev/pandas/pull/57545  2145945775
# 4   https://github.com/pandas-dev/pandas/issues/57544  2145685790
# 5     https://github.com/pandas-dev/pandas/pull/57543  2145519555
# 6     https://github.com/pandas-dev/pandas/pull/57542  2145462641
# 7     https://github.com/pandas-dev/pandas/pull/57540  2145330438
# 8   https://github.com/pandas-dev/pandas/issues/57539  2145327274
# 9   https://github.com/pandas-dev/pandas/issues/57531  2144832975
# 10  https://github.com/pandas-dev/pandas/issues/57526  2144633447
# 11  https://github.com/pandas-dev/pandas/issues/57525  2144585005
# 12  https://github.com/pandas-dev/pandas/issues/57524  2144427120
# 13  https://github.com/pandas-dev/pandas/issues/57523  2144203549
# 14  https://github.com/pandas-dev/pandas/issues/57521  2144084011
# 15  https://github.com/pandas-dev/pandas/issues/57517  2143376452
# 16  https://github.com/pandas-dev/pandas/issues/57512  2143259336
# 17    https://github.com/pandas-dev/pandas/pull/57508  2142894312
# 18  https://github.com/pandas-dev/pandas/issues/57505  2142533685
# 19  https://github.com/pandas-dev/pandas/issues/57500  2141564011
# 20    https://github.com/pandas-dev/pandas/pull/57494  2141248587
# 21    https://github.com/pandas-dev/pandas/pull/57492  2141207431
# 22    https://github.com/pandas-dev/pandas/pull/57491  2141204830
# 23    https://github.com/pandas-dev/pandas/pull/57487  2141087697
# 24    https://github.com/pandas-dev/pandas/pull/57478  2140653286
# 25    https://github.com/pandas-dev/pandas/pull/57476  2140635039
# 26    https://github.com/pandas-dev/pandas/pull/57475  2140629857
# 27    https://github.com/pandas-dev/pandas/pull/57471  2140109143
# 28    https://github.com/pandas-dev/pandas/pull/57469  2139979734
# 29    https://github.com/pandas-dev/pandas/pull/57467  2139718597
#
#                 node_id  number  \
# 0   PR_kwDOAA0YD85ng8fK   57548
# 1    I_kwDOAA0YD85_8l7U   57547
# 2   PR_kwDOAA0YD85nfr1q   57546
# 3   PR_kwDOAA0YD85nesL6   57545
# 4    I_kwDOAA0YD85_5JEe   57544
# 5   PR_kwDOAA0YD85ndONY   57543
# 6   PR_kwDOAA0YD85ndBnG   57542
# 7   PR_kwDOAA0YD85nckhO   57540
# 8    I_kwDOAA0YD85_3xiq   57539
# 9    I_kwDOAA0YD85_143P   57531
# 10   I_kwDOAA0YD85_1IJn   57526
# 11   I_kwDOAA0YD85_08Ut   57525
# 12   I_kwDOAA0YD85_0Vxw   57524
# 13   I_kwDOAA0YD85_zfMd   57523
# 14   I_kwDOAA0YD85_zCAr   57521
# 15   I_kwDOAA0YD85_wVRE   57517
# 16   I_kwDOAA0YD85_v4rI   57512
# 17  PR_kwDOAA0YD85nUQR1   57508
# 18   I_kwDOAA0YD85_tHg1   57505
# 19   I_kwDOAA0YD85_paxr   57500
# 20  PR_kwDOAA0YD85nOngy   57494
# 21  PR_kwDOAA0YD85nOfS4   57492
# 22  PR_kwDOAA0YD85nOexQ   57491
# 23  PR_kwDOAA0YD85nOHeA   57487
# 24  PR_kwDOAA0YD85nMtmU   57478
# 25  PR_kwDOAA0YD85nMqFf   57476
# 26  PR_kwDOAA0YD85nMpGU   57475
# 27  PR_kwDOAA0YD85nKxQk   57471
# 28  PR_kwDOAA0YD85nKT7e   57469
# 29  PR_kwDOAA0YD85nJb-B   57467
#
#                                                 title  ... closed_at  \
# 0   Fix accidental loss-of-precision for to_dateti...  ...       NaT
# 1   BUG: na_values dict form not working on index ...  ...       NaT
# 2   Add missing docstrings for Index.empty, Index....  ...       NaT
# 3   DOC: Improve to_string() docstring to clarify ...  ...       NaT
# 4           Potential regression induced by PR #57328  ...       NaT
# 5   PERF: Return RangeIndex from RangeIndex.join w...  ...       NaT
# 6   PERF: Return RangeIndex columns in str.extract...  ...       NaT
# 7             ES01 Extended Summaries for Categorical  ...       NaT
# 8   BUG: ADBC Postgres writer incorrectly names th...  ...       NaT
# 9   BUG: `sort_values` is sorting the index too wh...  ...       NaT
# 10  DOC: Clarify how groupby forms groups for mixe...  ...       NaT
# 11  ENH: Better documentation or default behavior ...  ...       NaT
# 12  BUG: Subtraction fails with matching index of ...  ...       NaT
# 13  BUG: Test failures on 32-bit x86 with pyarrow ...  ...       NaT
# 14  BUG: pandas >= 2.0 parses 'May' in ambiguous way.  ...       NaT
# 15  BUG: MultiIndex.factorize fails if index is 0-...  ...       NaT
# 16      BUG: Unexpected read_csv parse_dates behavior  ...       NaT
# 17                    BUG: Tick division is incorrect  ...       NaT
# 18  BUG: `std` using `numpy.float32` dtype gives i...  ...       NaT
# 19  BUG: Columns resulting from joining multiIndex...  ...       NaT
# 20  BUG: DateTimeIndex.is_year_start unexpected be...  ...       NaT
# 21  Remove dtype inference on object dtype indexes...  ...       NaT
# 22                         Remove is_foo_dtype checks  ...       NaT
# 23  CoW: Track references in unstack if there is n...  ...       NaT
# 24       PERF: Improve performance for astype is view  ...       NaT
# 25         TYP: simplify read_csv/fwf/table overloads  ...       NaT
# 26  REGR: Index.map adding back tz to tz-agnostic ...  ...       NaT
# 27  BUG: guess_datetime_format fails to infer time...  ...       NaT
# 28          DEPR: to_pytimedelta return Index[object]  ...       NaT
# 29  PERF: RangeIndex.append returns a RangeIndex w...  ...       NaT
#
#    author_association active_lock_reason  draft  \
# 0         CONTRIBUTOR                NaN    0.0
# 1                NONE                NaN    NaN
# 2                NONE                NaN    0.0
# 3                NONE                NaN    0.0
# 4              MEMBER                NaN    NaN
# 5              MEMBER                NaN    0.0
# 6              MEMBER                NaN    0.0
# 7         CONTRIBUTOR                NaN    0.0
# 8                NONE                NaN    NaN
# 9                NONE                NaN    NaN
# 10               NONE                NaN    NaN
# 11               NONE                NaN    NaN
# 12               NONE                NaN    NaN
# 13        CONTRIBUTOR                NaN    NaN
# 14               NONE                NaN    NaN
# 15        CONTRIBUTOR                NaN    NaN
# 16               NONE                NaN    NaN
# 17             MEMBER                NaN    0.0
# 18               NONE                NaN    NaN
# 19               NONE                NaN    NaN
# 20               NONE                NaN    0.0
# 21             MEMBER                NaN    0.0
# 22             MEMBER                NaN    0.0
# 23             MEMBER                NaN    0.0
# 24             MEMBER                NaN    0.0
# 25             MEMBER                NaN    0.0
# 26             MEMBER                NaN    1.0
# 27        CONTRIBUTOR                NaN    0.0
# 28               NONE                NaN    0.0
# 29             MEMBER                NaN    0.0
#
#                                          pull_request  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1                                                 NaN
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4                                                 NaN
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18                                                NaN
# 19                                                NaN
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                                  body  \
# 0   In Pandas 1.5.3, the `float(val)` cast was inl...
# 1   ### Pandas version checks\r\n\r\n- [X] I have ...
# 2                - [ All docstrings tests passed]\r\n
# 3   ## Summary\r\nThe current docstring for `to_st...
# 4   PR #57328 may have induced a performance regre...
# 5   Discovered in https://github.com/pandas-dev/pa...
# 6   Retry at https://github.com/pandas-dev/pandas/...
# 7   - [x] xref #57440 \r\n- [x] [Tests added and p...
# 8   ### Pandas version checks\r\n\r\n- [X] I have ...
# 9   ### Pandas version checks\r\n\r\n- [X] I have ...
# 10  ### Pandas version checks\n\n- [X] I have chec...
# 11  ### Feature Type\n\n- [ ] Adding new functiona...
# 12  ### Pandas version checks\r\n\r\n- [X] I have ...
# 13  ### Pandas version checks\n\n- [X] I have chec...
# 14  ### Pandas version checks\n\n- [X] I have chec...
# 15  ### Pandas version checks\n\n- [X] I have chec...
# 16  ### Pandas version checks\n\n- [X] I have chec...
# 17  - [ ] closes #57264 (Replace xxxx with the Git...
# 18  ### Pandas version checks\r\n\r\n- [X] I have ...
# 19  ### Pandas version checks\r\n\r\n- [X] I have ...
# 20  - [ ] closes #57377\r\n- [ ] [Tests added and ...
# 21  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 22  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 23  - [ ] xref #56633\r\n- [ ] All [code checks pa...
# 24  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 25                                               None
# 26  - [x] closes #57192 (Replace xxxx with the Git...
# 27  - [x] closes #57452(Replace xxxx with the GitH...
# 28  - [x] closes #57463 \r\n- [ ] [Tests added and...
# 29  Discovered in https://github.com/pandas-dev/pa...
#
#                                             reactions  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                          timeline_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#    performed_via_github_app state_reason
# 0                       NaN          NaN
# 1                       NaN          NaN
# 2                       NaN          NaN
# 3                       NaN          NaN
# 4                       NaN          NaN
# 5                       NaN          NaN
# 6                       NaN          NaN
# 7                       NaN          NaN
# 8                       NaN          NaN
# 9                       NaN          NaN
# 10                      NaN          NaN
# 11                      NaN          NaN
# 12                      NaN          NaN
# 13                      NaN          NaN
# 14                      NaN          NaN
# 15                      NaN          NaN
# 16                      NaN          NaN
# 17                      NaN          NaN
# 18                      NaN          NaN
# 19                      NaN          NaN
# 20                      NaN          NaN
# 21                      NaN          NaN
# 22                      NaN          NaN
# 23                      NaN          NaN
# 24                      NaN          NaN
# 25                      NaN          NaN
# 26                      NaN          NaN
# 27                      NaN          NaN
# 28                      NaN          NaN
# 29                      NaN          NaN
#
# [30 rows x 30 columns]

# %%
import requests
