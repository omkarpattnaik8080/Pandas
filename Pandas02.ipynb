# %% [markdown]
# <a href="https://colab.research.google.com/github/omkarpattnaik8080/Pandas/blob/main/Pandas02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("GeneralEsportData.csv")

# %%
df.head()
# Out:
#                     Game  ReleaseDate     Genre  TotalEarnings  \
# 0         Age of Empires         1997  Strategy      510716.46
# 1      Age of Empires II         1999  Strategy     3253232.59
# 2     Age of Empires III         2005  Strategy      115843.65
# 3      Age of Empires IV         2021  Strategy      994675.03
# 4  Age of Empires Online         2011  Strategy        9806.56
#
#    OfflineEarnings  PercentOffline  TotalPlayers  TotalTournaments
# 0        375857.63        0.735942           473               265
# 1       1139384.57        0.350232          1994              1613
# 2         41800.00        0.360831           166               163
# 3        409117.93        0.411308           542               327
# 4           775.00        0.079029            44                50
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
df.tail()
# Out:
#                                  Game  ReleaseDate                Genre  \
# 645                     Guitar Hero 5         2009  Music / Rhythm Game
# 646  Guitar Hero III: Legends of Rock         2007  Music / Rhythm Game
# 647           Guitar Hero: World Tour         2008  Music / Rhythm Game
# 648                   Just Dance 2014         2013  Music / Rhythm Game
# 649                              osu!         2007  Music / Rhythm Game
#
#      TotalEarnings  OfflineEarnings  PercentOffline  TotalPlayers  \
# 645       10500.00         10500.00         1.00000             3
# 646       19000.00         19000.00         1.00000             8
# 647           0.00             0.00             NaN             0
# 648           0.00             0.00             NaN             3
# 649      228205.84         26827.89         0.11756           854
#
#      TotalTournaments
# 645                 1
# 646                 2
# 647                 0
# 648                 1
# ...

# %%
df.columns
# Out:
# Index(['Game', 'ReleaseDate', 'Genre', 'TotalEarnings', 'OfflineEarnings',
#        'PercentOffline', 'TotalPlayers', 'TotalTournaments'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Game                 object
# ReleaseDate           int64
# Genre                object
# TotalEarnings       float64
# OfflineEarnings     float64
# PercentOffline      float64
# TotalPlayers          int64
# TotalTournaments      int64
# dtype: object

# %%
df.dtypes
# Out:
# Game                 object
# ReleaseDate           int64
# Genre                object
# TotalEarnings       float64
# OfflineEarnings     float64
# PercentOffline      float64
# TotalPlayers          int64
# TotalTournaments      int64
# dtype: object

# %%
df.dtypes=="object"
# Out:
# Game                 True
# ReleaseDate         False
# Genre                True
# TotalEarnings       False
# OfflineEarnings     False
# PercentOffline      False
# TotalPlayers        False
# TotalTournaments    False
# dtype: bool

# %%
df.dtypes[df.dtypes=="object"]
# Out:
# Game     object
# Genre    object
# dtype: object

# %%
df.describe()
# Out:
#        ReleaseDate  TotalEarnings  OfflineEarnings  PercentOffline  \
# count   650.000000   6.500000e+02     6.500000e+02      583.000000
# mean   2012.576923   2.527759e+06     1.774991e+06        0.659145
# std       7.436703   1.758171e+07     1.377120e+07        0.412233
# min    1981.000000   0.000000e+00     0.000000e+00        0.000000
# 25%    2007.000000   1.000000e+03     0.000000e+00        0.219244
# 50%    2015.000000   3.636129e+04     1.500000e+04        0.906896
# 75%    2019.000000   2.563600e+05     1.715892e+05        1.000000
# max    2023.000000   3.371080e+08     2.982906e+08        1.000000
#
#        TotalPlayers  TotalTournaments
# count    650.000000        650.000000
# mean     226.541538         94.078462
# std      964.342887        479.807202
# min        0.000000          0.000000
# 25%        4.000000          1.000000
# 50%       22.000000          5.000000
# 75%       99.500000         27.750000
# max    16272.000000       7245.000000
# ...

# %%
#how to filter object data type from the data
df.dtypes=="object"
# Out:
# Game                 True
# ReleaseDate         False
# Genre                True
# TotalEarnings       False
# OfflineEarnings     False
# PercentOffline      False
# TotalPlayers        False
# TotalTournaments    False
# dtype: bool

# %%
#if we want the complete series aaur yeah basically series deta hai
df.dtypes[df.dtypes=="object"]
# Out:
# Game     object
# Genre    object
# dtype: object

# %%
df.dtypes[df.dtypes=="object"].index #yahan par index hota hai column ka naam jahan par data type object hai
# Out:
# Index(['Game', 'Genre'], dtype='object')

# %%
df[df.dtypes[df.dtypes=="object"].index].describe()
# Out:
#                   Game          Genre
# count              650            650
# unique             650             12
# top     Age of Empires  Fighting Game
# freq                 1            183
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_0.groupby('Game').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('Genre').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
df.dtypes
# Out:
# Game                 object
# ReleaseDate           int64
# Genre                object
# TotalEarnings       float64
# OfflineEarnings     float64
# PercentOffline      float64
# TotalPlayers          int64
# TotalTournaments      int64
# dtype: object

# %%
df[df.dtypes[df.dtypes=="float"].index].describe()
# Out:
#        TotalEarnings  OfflineEarnings  PercentOffline
# count   6.500000e+02     6.500000e+02      583.000000
# mean    2.527759e+06     1.774991e+06        0.659145
# std     1.758171e+07     1.377120e+07        0.412233
# min     0.000000e+00     0.000000e+00        0.000000
# 25%     1.000000e+03     0.000000e+00        0.219244
# 50%     3.636129e+04     1.500000e+04        0.906896
# 75%     2.563600e+05     1.715892e+05        1.000000
# max     3.371080e+08     2.982906e+08        1.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3['TotalEarnings'].plot(kind='hist', bins=20, title='TotalEarnings')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_4['OfflineEarnings'].plot(kind='hist', bins=20, title='OfflineEarnings')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
df[df.dtypes[df.dtypes=="int"].index].describe()
# Out:
#        ReleaseDate  TotalPlayers  TotalTournaments
# count   650.000000    650.000000        650.000000
# mean   2012.576923    226.541538         94.078462
# std       7.436703    964.342887        479.807202
# min    1981.000000      0.000000          0.000000
# 25%    2007.000000      4.000000          1.000000
# 50%    2015.000000     22.000000          5.000000
# 75%    2019.000000     99.500000         27.750000
# max    2023.000000  16272.000000       7245.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_58['ReleaseDate'].plot(kind='hist', bins=20, title='ReleaseDate')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_59['TotalPlayers'].plot(kind='hist', bins=20, title='TotalPlayers')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
df[df.dtypes[df.dtypes=="int64"].index].describe()
# Out:
#        ReleaseDate  TotalPlayers  TotalTournaments
# count   650.000000    650.000000        650.000000
# mean   2012.576923    226.541538         94.078462
# std       7.436703    964.342887        479.807202
# min    1981.000000      0.000000          0.000000
# 25%    2007.000000      4.000000          1.000000
# 50%    2015.000000     22.000000          5.000000
# 75%    2019.000000     99.500000         27.750000
# max    2023.000000  16272.000000       7245.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['ReleaseDate'].plot(kind='hist', bins=20, title='ReleaseDate')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['TotalPlayers'].plot(kind='hist', bins=20, title='TotalPlayers')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
df.columns
# Out:
# Index(['Game', 'ReleaseDate', 'Genre', 'TotalEarnings', 'OfflineEarnings',
#        'PercentOffline', 'TotalPlayers', 'TotalTournaments'],
#       dtype='object')

# %%
df['Game']
# Out:
# 0                        Age of Empires
# 1                     Age of Empires II
# 2                    Age of Empires III
# 3                     Age of Empires IV
# 4                 Age of Empires Online
#                      ...
# 645                       Guitar Hero 5
# 646    Guitar Hero III: Legends of Rock
# 647             Guitar Hero: World Tour
# 648                     Just Dance 2014
# 649                                osu!
# Name: Game, Length: 650, dtype: object

# %%
#for seeing data from 4th row to 10th row
df[['Game']][4:11:2]
# Out:
#                      Game
# 4   Age of Empires Online
# 6                Among Us
# 8             Brawl Stars
# 10                chess24
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_11.groupby('Game').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
#agar aek naya column banana hai aaur usme dataframe ko store karna hai
df["new_col"]=0

# %%
#agar mujhe aek naya column banana hai jahan par mujhe kinhi 2 columns ko add karna hai respectively
df["new_col1"]=df['Game']+df['Genre']

# %%
df
# Out:
#                                  Game  ReleaseDate                Genre  \
# 0                      Age of Empires         1997             Strategy
# 1                   Age of Empires II         1999             Strategy
# 2                  Age of Empires III         2005             Strategy
# 3                   Age of Empires IV         2021             Strategy
# 4               Age of Empires Online         2011             Strategy
# ..                                ...          ...                  ...
# 645                     Guitar Hero 5         2009  Music / Rhythm Game
# 646  Guitar Hero III: Legends of Rock         2007  Music / Rhythm Game
# 647           Guitar Hero: World Tour         2008  Music / Rhythm Game
# 648                   Just Dance 2014         2013  Music / Rhythm Game
# 649                              osu!         2007  Music / Rhythm Game
#
#      TotalEarnings  OfflineEarnings  PercentOffline  TotalPlayers  \
# ...

# %%
#agar apko unique categories dekhne hai pandas ke andar there is a function called categorical
pd.Categorical(df["Genre"])
# Out:
# ['Strategy', 'Strategy', 'Strategy', 'Strategy', 'Strategy', ..., 'Music / Rhythm Game', 'Music / Rhythm Game', 'Music / Rhythm Game', 'Music / Rhythm Game', 'Music / Rhythm Game']
# Length: 650
# Categories (12, object): ['Battle Royale', 'Collectible Card Game', 'Fighting Game',
#                           'First-Person Shooter', ..., 'Role-Playing Game', 'Sports', 'Strategy',
#                           'Third-Person Shooter']

# %%
df.columns
# Out:
# Index(['Game', 'ReleaseDate', 'Genre', 'TotalEarnings', 'OfflineEarnings',
#        'PercentOffline', 'TotalPlayers', 'TotalTournaments', 'new_col',
#        'new_col1'],
#       dtype='object')

# %%
df.head()
# Out:
#                     Game  ReleaseDate     Genre  TotalEarnings  \
# 0         Age of Empires         1997  Strategy      510716.46
# 1      Age of Empires II         1999  Strategy     3253232.59
# 2     Age of Empires III         2005  Strategy      115843.65
# 3      Age of Empires IV         2021  Strategy      994675.03
# 4  Age of Empires Online         2011  Strategy        9806.56
#
#    OfflineEarnings  PercentOffline  TotalPlayers  TotalTournaments  new_col  \
# 0        375857.63        0.735942           473               265        0
# 1       1139384.57        0.350232          1994              1613        0
# 2         41800.00        0.360831           166               163        0
# 3        409117.93        0.411308           542               327        0
# 4           775.00        0.079029            44                50        0
#
#                         new_col1
# 0         Age of EmpiresStrategy
# 1      Age of Empires IIStrategy
# ...

# %%
#agar mujhe janna hai ki total tornaments mein kitne unique elements hai
df['TotalTournaments'].unique
# Out:
# <bound method Series.unique of 0       265
# 1      1613
# 2       163
# 3       327
# 4        50
#        ...
# 645       1
# 646       2
# 647       0
# 648       1
# 649     205
# Name: TotalTournaments, Length: 650, dtype: int64>

# %%
#agar mujhe data seta ko file karna hai aek column ke andar bounded by some condition
#for eg mujhe total players chahiye above 400
df["TotalPlayers"]>400
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 645    False
# 646    False
# 647    False
# 648    False
# 649     True
# Name: TotalPlayers, Length: 650, dtype: bool

# %%
len(df["TotalPlayers"]>400)
# Out:
# 650

# %%
#df[df["Total Players"]=="44"] df ke upar df lagaya taki interms of table hamko answer mile

# %%
df[(df["TotalPlayers"]>400) & (df["TotalTournaments"]>400)]
# Out:
#                                  Game  ReleaseDate  \
# 1                   Age of Empires II         1999
# 9                           Chess.com         2007
# 42                       StarCraft II         2010
# 43               StarCraft: Brood War         1998
# 55                       WarCraft III         2002
# 86     Call of Duty: Advanced Warfare         2014
# 106                    Counter-Strike         2000
# 110  Counter-Strike: Global Offensive         2012
# 148                         Overwatch         2016
# 163                 Rainbow Six Siege         2015
# 192                          VALORANT         2020
# 208                            Dota 2         2013
# 212               Heroes of the Storm         2015
# 214                 League of Legends         2009
# 253                        Brawlhalla         2015
# 382       Super Smash Bros. for Wii U         2014
# 383           Super Smash Bros. Melee         2001
# ...

# %%
df[df["TotalTournaments"]==max(df["TotalTournaments"])]
# Out:
#             Game  ReleaseDate     Genre  TotalEarnings  OfflineEarnings  \
# 42  StarCraft II         2010  Strategy    40148652.88       31811176.7
#
#     PercentOffline  TotalPlayers  TotalTournaments  new_col  \
# 42        0.792335          2213              7245        0
#
#                 new_col1
# 42  StarCraft IIStrategy

# %%
#agr dataframe se aek specific rows select karna hai
df[0:2]
# Out:
#                 Game  ReleaseDate     Genre  TotalEarnings  OfflineEarnings  \
# 0     Age of Empires         1997  Strategy      510716.46        375857.63
# 1  Age of Empires II         1999  Strategy     3253232.59       1139384.57
#
#    PercentOffline  TotalPlayers  TotalTournaments  new_col  \
# 0        0.735942           473               265        0
# 1        0.350232          1994              1613        0
#
#                     new_col1
# 0     Age of EmpiresStrategy
# 1  Age of Empires IIStrategy

# %%
df.loc[0:2,["ReleaseDate","Genre","TotalEarnings"]]
# Out:
#    ReleaseDate     Genre  TotalEarnings
# 0         1997  Strategy      510716.46
# 1         1999  Strategy     3253232.59
# 2         2005  Strategy      115843.65
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12['ReleaseDate'].plot(kind='hist', bins=20, title='ReleaseDate')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['TotalEarnings'].plot(kind='hist', bins=20, title='TotalEarnings')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_14.plot(kind='scatter', x='ReleaseDate', y='TotalEarnings', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...
