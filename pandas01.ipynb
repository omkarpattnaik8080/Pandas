# %% [markdown]
# <a href="https://colab.research.google.com/github/omkarpattnaik8080/Panda01/blob/main/pandas01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.read_csv("dailyActivity_merged.csv")
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    4/12/2016       13162       8.500000         8.500000
# 1    1503960366    4/13/2016       10735       6.970000         6.970000
# 2    1503960366    4/14/2016       10460       6.740000         6.740000
# 3    1503960366    4/15/2016        9762       6.280000         6.280000
# 4    1503960366    4/16/2016       12669       8.160000         8.160000
# ..          ...          ...         ...            ...              ...
# 935  8877689391     5/8/2016       10686       8.110000         8.110000
# 936  8877689391     5/9/2016       20226      18.250000        18.250000
# 937  8877689391    5/10/2016       10733       8.150000         8.150000
# 938  8877689391    5/11/2016       21420      19.559999        19.559999
# 939  8877689391    5/12/2016        8064       6.120000         6.120000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
#considers first row as a column schema
#if columns are not there it will bydefault give some column indexes
#it gives by default row indexes
#in pandas you will see 2 kinds of datatypes one is a frame another is a series

# %%
df=pd.read_csv("dailyActivity_merged.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['Id',
#  'ActivityDate',
#  'TotalSteps',
#  'TotalDistance',
#  'TrackerDistance',
#  'LoggedActivitiesDistance',
#  'VeryActiveDistance',
#  'ModeratelyActiveDistance',
#  'LightActiveDistance',
#  'SedentaryActiveDistance',
#  'VeryActiveMinutes',
#  'FairlyActiveMinutes',
#  'LightlyActiveMinutes',
#  'SedentaryMinutes',
#  'Calories']

# %%
#head gives u first 5 records

# %%
df.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    4/12/2016       13162           8.50             8.50
# 1  1503960366    4/13/2016       10735           6.97             6.97
# 2  1503960366    4/14/2016       10460           6.74             6.74
# 3  1503960366    4/15/2016        9762           6.28             6.28
# 4  1503960366    4/16/2016       12669           8.16             8.16
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                1.88                      0.55
# 1                       0.0                1.57                      0.69
# 2                       0.0                2.44                      0.40
# 3                       0.0                2.14                      1.26
# 4                       0.0                2.71                      0.41
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
df.head(3)
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    4/12/2016       13162           8.50             8.50
# 1  1503960366    4/13/2016       10735           6.97             6.97
# 2  1503960366    4/14/2016       10460           6.74             6.74
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                1.88                      0.55
# 1                       0.0                1.57                      0.69
# 2                       0.0                2.44                      0.40
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 6.06                      0.0                 25
# 1                 4.71                      0.0                 21
# 2                 3.91                      0.0                 30
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# ...

# %%
#tail is used to give the data from the last
df.tail()
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 935  8877689391     5/8/2016       10686       8.110000         8.110000
# 936  8877689391     5/9/2016       20226      18.250000        18.250000
# 937  8877689391    5/10/2016       10733       8.150000         8.150000
# 938  8877689391    5/11/2016       21420      19.559999        19.559999
# 939  8877689391    5/12/2016        8064       6.120000         6.120000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 935                       0.0                1.08                      0.20
# 936                       0.0               11.10                      0.80
# 937                       0.0                1.35                      0.46
# 938                       0.0               13.22                      0.41
# 939                       0.0                1.82                      0.04
#
# ...

# %%
#what all data types we are having in the column
df.dtypes
# Out:
# Id                            int64
# ActivityDate                 object
# TotalSteps                    int64
# TotalDistance               float64
# TrackerDistance             float64
# LoggedActivitiesDistance    float64
# VeryActiveDistance          float64
# ModeratelyActiveDistance    float64
# LightActiveDistance         float64
# SedentaryActiveDistance     float64
# VeryActiveMinutes             int64
# FairlyActiveMinutes           int64
# LightlyActiveMinutes          int64
# SedentaryMinutes              int64
# Calories                      int64
# dtype: object

# %%
#if i want to select couple of columns
df.columns
# Out:
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories'],
#       dtype='object')

# %%
df[ 'ActivityDate']
# Out:
# 0      4/12/2016
# 1      4/13/2016
# 2      4/14/2016
# 3      4/15/2016
# 4      4/16/2016
#          ...
# 935     5/8/2016
# 936     5/9/2016
# 937    5/10/2016
# 938    5/11/2016
# 939    5/12/2016
# Name: ActivityDate, Length: 940, dtype: object

# %%
type(df['ActivityDate'])
# Out:
# pandas.core.series.Series

# %%
#conversion of a series into a list
list(df['ActivityDate'])
# Out:
# ['4/12/2016',
#  '4/13/2016',
#  '4/14/2016',
#  '4/15/2016',
#  '4/16/2016',
#  '4/17/2016',
#  '4/18/2016',
#  '4/19/2016',
#  '4/20/2016',
#  '4/21/2016',
#  '4/22/2016',
#  '4/23/2016',
#  '4/24/2016',
#  '4/25/2016',
#  '4/26/2016',
#  '4/27/2016',
#  '4/28/2016',
#  '4/29/2016',
#  '4/30/2016',
#  '5/1/2016',
#  '5/2/2016',
#  '5/3/2016',
#  '5/4/2016',
#  '5/5/2016',
#  '5/6/2016',
#  '5/7/2016',
#  '5/8/2016',
#  '5/9/2016',
#  '5/10/2016',
#  '5/11/2016',
#  '5/12/2016',
#  '4/12/2016',
#  '4/13/2016',
#  '4/14/2016',
#  '4/15/2016',
#  '4/16/2016',
#  '4/17/2016',
#  '4/18/2016',
#  '4/19/2016',
#  '4/20/2016',
#  '4/21/2016',
#  '4/22/2016',
#  '4/23/2016',
#  '4/24/2016',
#  '4/25/2016',
#  '4/26/2016',
#  '4/27/2016',
#  '4/28/2016',
#  '4/29/2016',
#  '4/30/2016',
#  '5/1/2016',
#  '5/2/2016',
#  '5/3/2016',
#  '5/4/2016',
#  '5/5/2016',
#  '5/6/2016',
#  '5/7/2016',
#  '5/8/2016',
#  '5/9/2016',
#  '5/10/2016',
#  '5/11/2016',
#  '5/12/2016',
#  '4/12/2016',
# ...

# %%
df.columns
# Out:
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories'],
#       dtype='object')

# %%
df[['ActivityDate','VeryActiveMinutes']] #if i want to pass multiple columns then pass it as a list
# Out:
#     ActivityDate  VeryActiveMinutes
# 0      4/12/2016                 25
# 1      4/13/2016                 21
# 2      4/14/2016                 30
# 3      4/15/2016                 29
# 4      4/16/2016                 36
# ..           ...                ...
# 935     5/8/2016                 17
# 936     5/9/2016                 73
# 937    5/10/2016                 18
# 938    5/11/2016                 88
# 939    5/12/2016                 23
#
# [940 rows x 2 columns]

# %%
df1=pd.read_excel("Historicalinvesttemp.xlsx")

# %%
df1.head()
# Out:
#   Unnamed: 0                        Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0        NaN                               NaN        NaN        NaN
# 1        NaN                               NaN        NaN        NaN
# 2        NaN                               NaN        NaN        NaN
# 3        NaN                               NaN        NaN        NaN
# 4        NaN  Annual Returns on Investments in        NaN        NaN

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3'], dtype='object')

# %%
df1.dtypes
# Out:
# Unnamed: 0    object
# Unnamed: 1    object
# Unnamed: 2    object
# Unnamed: 3    object
# dtype: object

# %%
df1.tail(3)
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3
# 87       2009     0.2646     -0.149      0.001
# 88        NaN     stocks     tbills      bonds
# 89   averages        NaN        NaN        NaN

# %%
df1
# Out:
#    Unnamed: 0                        Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0         NaN                               NaN        NaN        NaN
# 1         NaN                               NaN        NaN        NaN
# 2         NaN                               NaN        NaN        NaN
# 3         NaN                               NaN        NaN        NaN
# 4         NaN  Annual Returns on Investments in        NaN        NaN
# ..        ...                               ...        ...        ...
# 85       2007                            0.0549     0.0988     0.0466
# 86       2008                             -0.37     0.2587      0.016
# 87       2009                            0.2646     -0.149      0.001
# 88        NaN                            stocks     tbills      bonds
# 89   averages                               NaN        NaN        NaN
#
# [90 rows x 4 columns]

# %%
df1['Unnamed: 0']
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#         ...
# 85        2007
# 86        2008
# 87        2009
# 88         NaN
# 89    averages
# Name: Unnamed: 0, Length: 90, dtype: object

# %%
df1[['Unnamed: 0', 'Unnamed: 1']]
# Out:
#    Unnamed: 0                        Unnamed: 1
# 0         NaN                               NaN
# 1         NaN                               NaN
# 2         NaN                               NaN
# 3         NaN                               NaN
# 4         NaN  Annual Returns on Investments in
# ..        ...                               ...
# 85       2007                            0.0549
# 86       2008                             -0.37
# 87       2009                            0.2646
# 88        NaN                            stocks
# 89   averages                               NaN
#
# [90 rows x 2 columns]

# %%
 #pandas read only tabular data
